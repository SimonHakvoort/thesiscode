# %%
from src.neural_networks.get_data import get_tf_data, stack_1d_features, normalize_1d_features_with_mean_std, load_cv_data, make_importance_sampling_dataset
from src.neural_networks.nn_forecast import NNForecast
from src.visualization.twcrpss_plot import make_twcrpss_plot_tf
from src.visualization.brier_score import make_brier_skill_plot_tf
from src.visualization.pit import make_cpit_diagram_tf, comp_multiple_pit_scores
from src.visualization.reliability_diagram import make_reliability_and_sharpness_tf
from src.training.training import load_model
from src.visualization.plot_forecasts import plot_forecast_pdf_tf
from src.climatology.climatology import Climatology
from src.visualization.brier_score import get_brier_scores_tf
from src.models.emos import BootstrapEmos, EMOS

import sklearn

from scipy.stats import norm, pareto

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pickle
import optuna
import time
# Out:
# 2024-06-24 12:48:11.652056: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-24 12:48:11.654572: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-24 12:48:11.686641: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-24 12:48:16.930053: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
filepath = '/net/pc200239/nobackup/users/hakvoort/hyperopt/hyperopt_emos/'

study = optuna.load_study(study_name='MOTPE_CRPS_CRPS12_long_run', storage=f'sqlite:///{filepath}/study.db')
study.set_metric_names(['CRPS', 'twCRPS12'])
# Out:
# /tmp/ipykernel_504226/2379815591.py:4: ExperimentalWarning: set_metric_names is experimental (supported from v3.2.0). The interface can change in the future.
#   study.set_metric_names(['CRPS', 'twCRPS12'])

# %%
filepath = '/net/pc200239/nobackup/users/hakvoort/hyperopt/hyperopt_emos/'

study = optuna.load_study(study_name='MOTPE_CRPS_CRPS12_linear_constant_from_zero', storage=f'sqlite:///{filepath}/study.db')
study.set_metric_names(['CRPS', 'twCRPS12'])
# Out:
# /tmp/ipykernel_504226/2842926713.py:4: ExperimentalWarning: set_metric_names is experimental (supported from v3.2.0). The interface can change in the future.
#   study.set_metric_names(['CRPS', 'twCRPS12'])

# %%
df = study.trials_dataframe()

new_column_names = {
    'params_chain_function_mean': 'cf_mean',
    'params_chain_function_std': 'cf_std',
    'params_chain_function_constant': 'cf_constant',
    'values_CRPS': 'CRPS',
    'values_twCRPS12': 'twCRPS12',
    'params_forecast_distribution': 'forecast_distribution',
    'params_distribution_2': 'distribution_2',
}

df.rename(columns=new_column_names, inplace=True)

# %%
df = df[0: 180]

# %%
length = 8
top_CRPS = df.sort_values('CRPS').head(length)
top_twCRPS12 = df.sort_values('twCRPS12').head(length)

# %%
pareto_front = study.best_trials
best_runs = [trial.number for trial in pareto_front]

pareto_trials = df['number'].isin(best_runs)

my_run = df[pareto_trials]

my_run = my_run.sort_values('CRPS')

# %%
all_params = ['cf_mean',
           'cf_std', 
           'cf_constant',
             'forecast_distribution', 
              'distribution_2',
                'CRPS',
             'twCRPS12',
             ]

# %%
features_names = ['wind_speed', 'press', 'kinetic', 'humid', 'geopot']

features_names_dict = {name: 1 for name in features_names}

features_names_dict['wind_speed'] = 15

ignore = ['229', '285', '323']

# %%
train_data_original, test_data, data_info = load_cv_data(0, features_names_dict)

train_data = train_data_original.batch(len(train_data_original))

# %%
X, y = next(iter(train_data))

print(y.shape)

y = y.numpy()
# Out:
# (23513,)

# %%
def silvermans_rule(data):
    # Calculate the standard deviation of the data
    sigma = np.std(data, ddof=1)
    
    # Calculate the interquartile range (IQR) of the data
    IQR = np.percentile(data, 75) - np.percentile(data, 25)
    
    # Calculate the bandwidth using Silverman's rule
    n = len(data)
    h = 0.9 * min(sigma, IQR / 1.34) * n**(-1/5)
    
    return h

def gaussian_kernel(x):
    return norm.pdf(x)

def kde_function(data, bandwidth):
    def kde(points):
        N = len(data)
        kde_values = np.zeros(len(points))
        for i in range(len(points)):
            kde_values[i] = (1 / (N * bandwidth)) * np.sum(gaussian_kernel((points[i] - data) / bandwidth))
        return kde_values
    return kde

# %%
bandwith = silvermans_rule(y)

kde = kde_function(y, bandwith)

# %%
minimum = np.min(kde(y))
maximum = np.max(kde(y))

# %%
def get_weight_function(data, alpha, epsilon):
    bandwith = silvermans_rule(data)
    kde = kde_function(data, bandwith)

    max = np.max(kde(data))
    min = np.min(kde(data))

    def f_w_double_prime(points):
        p_prime = (kde(points) - min) / (max - min)

        return np.maximum(1 - alpha * p_prime, epsilon)
    
    normalization_constant = np.sum(f_w_double_prime(data)) / len(data)

    def weight_function(points):
        return f_w_double_prime(points) / normalization_constant
    
    return weight_function

# %%
alpha = 1.2
epsilon = 0.0001
my_weight = get_weight_function(y, alpha, epsilon)

x = np.linspace(0, 30, 20000)
weights = my_weight(x)
degree = 60

p = np.polynomial.Polynomial.fit(x, weights, degree)

# Generate points for plotting the fitted polynomial
x_fit = np.linspace(0, 30, 1000)
y_fit = p(x_fit)
# Out:
# /usr/people/hakvoort/.local/lib/python3.12/site-packages/numpy/polynomial/polynomial.py:1362: RankWarning: The fit may be poorly conditioned
#   return pu._fit(polyvander, x, y, deg, rcond, full, w)

# %%
min_y = kde(y).min()
max_y = kde(y).max()

# %% [markdown]
# ## Histogram of the observations

# %%
plt.hist(y, bins = 50, density=True, color='skyblue', edgecolor='black', alpha=0.7)
plt.xlim(0, np.max(y))
plt.xlabel('Observed Wind Speed')
plt.ylabel('Frequency')
plt.grid(True, color='grey', linestyle='--', linewidth=0.5, alpha=0.5)
plt.show()

# %%
y_9 = y[y < 9]
y_12 = y[(9 <= y) & (y < 12)]
y_15 = y[(12 <= y) & (y < 15)]
y_big = y[y >= 15]

# %%
print(len(y_9))
print(len(y_12) * 10)
print(len(y_15) * 20)
print(len(y_big) * 30)
# Out:
# 20389
# 20130
# 16520
# 8550

# %%
new_data = make_importance_sampling_dataset(train_data_original)
dataset_length = [i for i,_ in enumerate(new_data)][-1] + 1
print(dataset_length)
# Out:
# 38469
# 2024-06-20 16:57:06.475265: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
new_data = new_data.shuffle(new_data.cardinality())
print(new_data.cardinality())
# Out:
# tf.Tensor(-2, shape=(), dtype=int64)

# %%
X, y, weight = next(iter(new_data))
print(weight.numpy(), y.numpy())
# Out:
# 0.125 12.93

# %%
print(len(y_9) + len(y_12) * 4 + len(y_15) * 8 + len(y_big) * 12)
# Out:
# 38469

# %%
x = np.linspace(0, 22.5, 2000)

plt.plot(x, (kde(x) - min_y)/(max_y-min_y))
plt.ylim(0,1)
plt.xlim(x[0], x[-1])
plt.show()

# %%
x = np.linspace(0, 22.5, 100)
epsilon = 0.00001
alphas = [0,0.4, 0.8, 1.2, 1.6, 2]

for alpha in alphas:
    weight_function = get_weight_function(y, alpha, epsilon)
    plt.plot(x, weight_function(x), label=alpha)

plt.xlabel('Observed Wind speed')
plt.ylabel('Weight')
plt.grid()
plt.legend()
plt.xlim(x[0], x[-1])
plt.show()

# %%
x = np.linspace(0, 22.5, 20000)
weights = my_weight(x)

plt.plot(x_fit, y_fit, label='polynomial approximation of degree 60')
plt.plot(x, weights, label=r'$f_{1.2}(x)$')
plt.legend()
plt.ylim(-0.1, 4)
plt.xlim(x[0], x[-1])
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
plt.show()

# %%
print(np.min(y_fit))
# Out:
# -0.0218842253375775

# %%
x = np.linspace(0, 30, 20000)
start = time.time()
weights = my_weight(x)
end = time.time()

print("Time elapsed to evlaute the alpha weight function for 20.000 elements: ", end-start)
# Out:
# Time elapsed to evlaute the alpha weight function for 20.000 elements:  10.69624948501587

# %%
c = 0.05
mu = 8
sigma = 1
start = time.time()
result = c + norm.cdf(x, loc=mu, scale=sigma)
end = time.time()

print("Time elapsed to evaluate the Gaussian CDF weight function for 20.000 elements: ", end - start)
# Out:
# Time elapsed to evaluate the Gaussian CDF weight function for 20.000 elements:  0.0016102790832519531

# %%
c = 0.001
mu = 8.3
std = 2
x = np.linspace(0, 22.5, 100)
y__ = c + norm.cdf(x, loc=mu, scale=std)
y__ *= 4
plt.plot(x, y__)
plt.xlabel('Observed Wind speed')
plt.ylabel('Weight')
plt.grid()
plt.xlim(x[0], x[-1])
plt.show()

# %% [markdown]
# ### Pros and ons for using $f_w(\alpha)$ as weight function
#
# | Upsides                                      | Downsides                                  |
# |----------------------------------------------|--------------------------------------------|
# | 1  parameter, leading to easier hyperopt     | Less flexible than the Gaussian cdf        |
# | More inteprable                              | Evaluation of a single epoch is $\mathcal{O}(n^2) $ so we probably need to to perform polynomial approximation|
# | The weight function is linked to the data    | The actual effect on performance is most likely limited, since the Gaussian cdf can make a good approximation of $f_w(\alpha)$                |
# |  | Will take time to implement correctly |
# | | Does not really help with a better answer to my research question |
#
# Kiri and Bastien agreed with these points, and think that this is something to mention in my discussion.

# %% [markdown]
# ## Oversampling / Undersampling Methods
#
# Chiheb suggest a few methods to perform this
#
# - I think that for EMOS with linear regression the effect will be limited, and at best it will result in optimizing over a scoring rule that is improper since certain samples appear more often in the dataset.
#
# - With CNNs this could be explored. However this problem is not really related to my research question, so I don't know how to combine this with the rest of my thesis.
#
# - Since the data represent metereological variables, it might not be wise to interpolate/add random noise to the variables. I also then need to normalize the grid for CNNs
#
# - Kiri and Bastien said they have not seen any papers about generating synthetic samples to the data.
#
# - My idea was that we would only oversample the extreme cases (top 15%), and then reweight the samples to ensure that the total weight of each sample would equal 1.

# %%
display(top_CRPS[all_params])
# Out:
#        cf_mean    cf_std  cf_constant forecast_distribution distribution_2  \
# 24    8.014864  0.051787     0.905043  distr_mixture_linear      distr_gev
# 32    2.381427  0.000149     0.846054  distr_mixture_linear      distr_gev
# 69    7.214490  5.441655     0.245422  distr_mixture_linear      distr_gev
# 74   11.130756  9.455881     0.088957  distr_mixture_linear      distr_gev
# 45    4.450143  4.945555     0.413133  distr_mixture_linear      distr_gev
# 160   0.429430  1.295928     0.031033  distr_mixture_linear      distr_gev
# 89    7.510774  1.363924     0.396717  distr_mixture_linear      distr_gev
# 176   8.184592  0.047243     0.860618    distr_trunc_normal            NaN
#
#          CRPS  twCRPS12
# 24   0.899754  0.059584
# 32   0.900814  0.059747
# 69   0.900886  0.059634
# 74   0.900919  0.059736
# 45   0.901207  0.059513
# 160  0.901321  0.059876
# 89   0.901359  0.059626
# 176  0.901405  0.059753

# %%
display(top_twCRPS12[all_params])
# Out:
#       cf_mean    cf_std  cf_constant forecast_distribution    distribution_2  \
# 51   9.649472  1.084596     0.001125  distr_mixture_linear         distr_gev
# 167  8.063486  0.427858     0.062220    distr_trunc_normal               NaN
# 66   9.860208  0.301864     0.000522      distr_log_normal               NaN
# 165  8.830960  1.068426     0.015801    distr_trunc_normal               NaN
# 30   9.571495  0.005566     0.004899  distr_mixture_linear  distr_log_normal
# 82   7.050564  2.405172     0.061703  distr_mixture_linear  distr_log_normal
# 115  9.578896  0.507889     0.026211             distr_gev               NaN
# 10   8.242517  0.047522     0.030665         distr_mixture  distr_log_normal
#
#          CRPS  twCRPS12
# 51   0.936089  0.059160
# 167  0.910241  0.059180
# 66   1.019796  0.059257
# 165  0.921362  0.059311
# 30   0.937670  0.059344
# 82   0.904452  0.059380
# 115  0.922650  0.059393
# 10   0.919068  0.059395

# %%
display(my_run[all_params])
# Out:
#       cf_mean    cf_std  cf_constant forecast_distribution    distribution_2  \
# 24   8.014864  0.051787     0.905043  distr_mixture_linear         distr_gev
# 45   4.450143  4.945555     0.413133  distr_mixture_linear         distr_gev
# 162  9.614099  0.077247     0.925251  distr_mixture_linear  distr_log_normal
# 82   7.050564  2.405172     0.061703  distr_mixture_linear  distr_log_normal
# 167  8.063486  0.427858     0.062220    distr_trunc_normal               NaN
# 51   9.649472  1.084596     0.001125  distr_mixture_linear         distr_gev
#
#          CRPS  twCRPS12
# 24   0.899754  0.059584
# 45   0.901207  0.059513
# 162  0.902346  0.059471
# 82   0.904452  0.059380
# 167  0.910241  0.059180
# 51   0.936089  0.059160
