# %%
import pickle as pkl
import numpy as np

from src.models.train_emos import train_emos, train_and_test_emos
from pit import make_cpit_diagram_emos, make_cpit_hist_emos 
from brier_score import brier_skill_plot, brier_plot
from src.models.get_data import get_tensors, get_normalized_tensor
from src.models.emos import EMOS
from scoring_tables import make_table
from twcrpss_plot import make_twcrpss_plot
from src.models.emos import EMOS
from reliability_diagram import make_reliability_diagram

# %%
neighbourhood_size = 11
parameter_names = ['wind_speed', 'press', 'kinetic', 'humid', 'geopot']
ignore = ['229', '285', '323']
train_folds = [1, 2]
train_data = get_normalized_tensor(neighbourhood_size, parameter_names, train_folds, ignore)

X_train = train_data['X']
y_train = train_data['y']
variances_train = train_data['variances']
mean_train = train_data['mean']
std_train = train_data['std']


print(X_train.shape)
# Out:
# (15733, 5)

# %%
test_fold = 3

X_test, y_test, variances_test = get_tensors(neighbourhood_size, parameter_names, test_fold, ignore)
X_test = (X_test - mean_train) / std_train

print(X_test.shape)
# Out:
# (7780, 5)

# %%
# load the dictionary with the data from /net/pc200239/nobackup/users/hakvoort/models
with open('/net/pc200239/nobackup/users/hakvoort/models/emos_crps.pkl', 'rb') as f:
    models_crps = pkl.load(f)

with open('/net/pc200239/nobackup/users/hakvoort/models/emos_twcrps_mean_12_std_4.pkl', 'rb') as f:
    models_twcrps_mean_12_std_4 = pkl.load(f)

with open('/net/pc200239/nobackup/users/hakvoort/models/emos_twcrps_mean_13_std_2.pkl', 'rb') as f:
    models_twcrps_mean_13_std_2 = pkl.load(f)

# %%
emos_crps = {}

for key, value in models_crps.items():
    emos_crps[key] = EMOS(value)

emos_twcrps = {}

for key, value in models_twcrps_mean_12_std_4.items():
    emos_twcrps[key] = EMOS(value)
# Out:
# Using given parameters for Truncated Normal distribution
# Using given parameters for Log Normal distribution
# Using given parameters for Generalized Extreme Value distribution
# Using given parameters for Frechet distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Log Normal distribution
# Using given weight parameter for Mixture distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Generalized Extreme Value distribution
# Using given weight parameter for Mixture distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Frechet distribution
# Using given weight parameter for Mixture distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Log Normal distribution
# Using given weight parameters for weights in Mixture Linear distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Generalized Extreme Value distribution
# Using given weight parameters for weights in Mixture Linear distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Frechet distribution
# Using given weight parameters for weights in Mixture Linear distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Log Normal distribution
# Using given parameters for Generalized Extreme Value distribution
# Using given parameters for Frechet distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Log Normal distribution
# Using given weight parameter for Mixture distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Generalized Extreme Value distribution
# Using given weight parameter for Mixture distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Frechet distribution
# Using given weight parameter for Mixture distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Log Normal distribution
# Using given weight parameters for weights in Mixture Linear distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Generalized Extreme Value distribution
# Using given weight parameters for weights in Mixture Linear distribution
# Using given parameters for Truncated Normal distribution
# Using given parameters for Frechet distribution
# Using given weight parameters for weights in Mixture Linear distribution

# %%
# pit diagrams:
c = 0
make_cpit_diagram_emos(emos_crps, X_test, y_test, variances_test, "crps models", c)

make_cpit_diagram_emos(emos_twcrps, X_test, y_test, variances_test, "twcrps", c)
# Out:
# There are 7780 values in the PIT diagram
# There are 7780 values in the PIT diagram

# %%
c = 12
bins = 20
make_cpit_hist_emos(base_model, X_test, y_test, variances_test, bins, "crps models", c)
# Out:
# There are 423 values in the PIT histogram

# %%
base_model = emos_crps.pop('crps_tn')

# %%
samples = 2000
print('crps_tn: ', base_model.loss_CRPS_sample_general(X_test, y_test, variances_test, samples).numpy())
for key, model in emos_crps.items():
    print(key, model.loss_CRPS_sample_general(X_test, y_test, variances_test, samples).numpy())
# Out:
# crps_tn:  0.89047813
# crps_ln 1.0310996
# crps_gev 0.89118224
# crps_frechet 0.89456207
# crps_mix_tn_ln 0.89023423
# crps_mix_tn_gev 0.8848873
# crps_mix_tn_frechet 0.8846378
# crps_mixlinear_tn_ln 0.8957225
# crps_mixlinear_tn_gev 0.8893961
# crps_mixlinear_tn_frechet 0.88827074

# %%
for key, model in emos_twcrps.items():
    print(key, model.loss_CRPS_sample_general(X_test, y_test, variances_test, samples).numpy())
# Out:
# twcrps_tn 0.8988112
# twcrps_ln 1.1885184
# twcrps_gev 0.90077835
# twcrps_frechet 0.9035242
# twcrps_mix_tn_ln 0.915186
# twcrps_mix_tn_gev 0.901302
# twcrps_mix_tn_frechet 0.89570796
# twcrps_mixlinear_tn_ln 0.905796
# twcrps_mixlinear_tn_gev 0.8976024
# twcrps_mixlinear_tn_frechet 0.89555806

# %%
values = np.linspace(0,16, 160)
ylim = [-0.1, 0.1]
brier_skill_plot(base_model, emos_crps, X_test, y_test, variances_test, values, ylim)

# %%
ylim = [-2, 2]
brier_skill_plot(base_model, emos_twcrps, X_test, y_test, variances_test, values, ylim)

# %%
values = np.linspace(0,16, 80)
ylim = [-0.1, 0.1]
make_twcrpss_plot(base_model, emos_crps, X_test, y_test, variances_test, values, ylim)
make_twcrpss_plot(base_model, emos_twcrps, X_test, y_test, variances_test, values, ylim)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 4
#       2 ylim = [-0.1, 0.1]
#       3 make_twcrpss_plot(base_model, emos_crps, X_test, y_test, variances_test, values, ylim)
# ----> 4 make_twcrpss_plot(base_model, emos_twcrps, X_test, y_test, variances_test, values, ylim)
#
# File ~/thesiscode/src/visualization/twcrpss_plot.py:22, in make_twcrpss_plot(base_model, model_dict, X, y, variances, thresholds, sample_size)
#       9 """
#      10 Makes a plot of the twCRPSS for different thresholds for the models in model_dict, compared to base_model
#      11
#    (...)
#      19 - sample_size: the number of samples to use for the twCRPSS calculation
#      20 """
#      21 for model_name, model in model_dict.items():
# ---> 22     scores = [comp_twcrpss(base_model, model, X, y, variances, threshold, sample_size) for threshold in thresholds]
#      23     plt.plot(thresholds, scores, label = model_name)
#      25 plt.xlabel('Threshold (m/s)')
#
# File ~/thesiscode/src/visualization/twcrpss_plot.py:22, in <listcomp>(.0)
#       9 """
#      10 Makes a plot of the twCRPSS for different thresholds for the models in model_dict, compared to base_model
#      11
#    (...)
#      19 - sample_size: the number of samples to use for the twCRPSS calculation
#      20 """
#      21 for model_name, model in model_dict.items():
# ---> 22     scores = [comp_twcrpss(base_model, model, X, y, variances, threshold, sample_size) for threshold in thresholds]
#      23     plt.plot(thresholds, scores, label = model_name)
#      25 plt.xlabel('Threshold (m/s)')
#
# File ~/thesiscode/src/visualization/twcrpss_plot.py:5, in comp_twcrpss(model_ref, model, X, y, variances, threshold, sample_size)
#       4 def comp_twcrpss(model_ref, model, X, y, variances, threshold, sample_size = 1000):
# ----> 5     return 1 - model.loss_twCRPS_indicator_sample(X, y, variances, threshold, sample_size).numpy() / model_ref.loss_twCRPS_indicator_sample(X, y, variances, threshold, sample_size).numpy()
#
# File ~/thesiscode/src/models/emos.py:379, in EMOS.loss_twCRPS_indicator_sample(self, X, y, variance, threshold, samples)
#     377 def loss_twCRPS_indicator_sample(self, X, y, variance, threshold, samples):
#     378     chain_function = lambda x: self.chain_function_indicator_general(x, threshold)
# --> 379     return self.loss_twCRPS_sample_general(X, y, variance, chain_function, samples)
#
# File ~/thesiscode/src/models/emos.py:387, in EMOS.loss_twCRPS_sample_general(self, X, y, variance, chain_function, samples)
#     385 forecast_distribution = self.forecast_distribution.get_distribution(X, variance)
#     386 X_1 = forecast_distribution.sample(samples)
# --> 387 X_2 = forecast_distribution.sample(samples)
#     388 vX_1 = chain_function(X_1)
#     389 vX_2 = chain_function(X_2)
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_probability/python/distributions/distribution.py:1205, in Distribution.sample(self, sample_shape, seed, name, **kwargs)
#    1190 """Generate samples of the specified shape.
#    1191
#    1192 Note that a call to `sample()` without arguments will generate a single
#    (...)
#    1202   samples: a `Tensor` with prepended dimensions `sample_shape`.
#    1203 """
#    1204 with self._name_and_control_scope(name):
# -> 1205   return self._call_sample_n(sample_shape, seed, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_probability/python/distributions/distribution.py:1182, in Distribution._call_sample_n(self, sample_shape, seed, **kwargs)
#    1178 sample_shape = ps.convert_to_shape_tensor(
#    1179     ps.cast(sample_shape, tf.int32), name='sample_shape')
#    1180 sample_shape, n = self._expand_sample_shape_to_vector(
#    1181     sample_shape, 'sample_shape')
# -> 1182 samples = self._sample_n(
#    1183     n, seed=seed() if callable(seed) else seed, **kwargs)
#    1184 samples = tf.nest.map_structure(
#    1185     lambda x: tf.reshape(x, ps.concat([sample_shape, ps.shape(x)[1:]], 0)),
#    1186     samples)
#    1187 return self._set_sample_static_shape(samples, sample_shape, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_probability/python/distributions/truncated_normal.py:257, in TruncatedNormal._sample_n(self, n, seed)
#     248 batch_shape = self._batch_shape_tensor(
#     249     loc=loc, scale=scale, low=low, high=high)
#     250 sample_and_batch_shape = ps.concat([[n], batch_shape], 0)
#     251 return tf.random.stateless_parameterized_truncated_normal(
#     252     shape=sample_and_batch_shape,
#     253     means=loc,
#     254     stddevs=scale,
#     255     minvals=low,
#     256     maxvals=high,
# --> 257     seed=samplers.sanitize_seed(seed))
#
# File ~/.local/lib/python3.11/site-packages/tensorflow_probability/python/internal/samplers.py:130, in sanitize_seed(seed, salt, name)
#     127     salt = None
#     128   # Convert "stateful-indicating" `int`/`None` seed to stateless Tensor seed
#     129   # by way of a stateful sampler.
# --> 130   seed = tf.random.uniform([2], seed=seed, minval=np.iinfo(SEED_DTYPE).min,
#     131                            maxval=np.iinfo(SEED_DTYPE).max,
#     132                            dtype=SEED_DTYPE, name='seed')
#     134 # TODO(b/223267515): In JAX mode, raise a user-friendly error if seed is
#     135 # not a PRNGKey.
#     136
#     137 # TODO(b/159209541): Consider ignoring salts for stateless seeds, for
#     138 # performance and because using stateless seeds already requires the
#     139 # discipline of splitting.
#     141 if salt is not None:
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/ops/random_ops.py:305, in random_uniform(shape, minval, maxval, dtype, seed, name)
#     303 seed1, seed2 = random_seed.get_seed(seed)
#     304 if dtype.is_integer:
# --> 305   result = gen_random_ops.random_uniform_int(
#     306       shape, minval, maxval, seed=seed1, seed2=seed2, name=name)
#     307 else:
#     308   result = gen_random_ops.random_uniform(
#     309       shape, dtype, seed=seed1, seed2=seed2)
#
# File ~/.local/lib/python3.11/site-packages/tensorflow/python/ops/gen_random_ops.py:837, in random_uniform_int(shape, minval, maxval, seed, seed2, name)
#     835 if tld.is_eager:
#     836   try:
# --> 837     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     838       _ctx, "RandomUniformInt", name, shape, minval, maxval, "seed", seed,
#     839       "seed2", seed2)
#     840     return _result
#     841   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
